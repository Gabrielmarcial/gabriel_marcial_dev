# %% [markdown]
# # 🗺️ **Curso de  Python**
# ### 📆 **Ano: 2026**
# ### 👨‍🏫 **Professor: Gabriel Marcial**
#
# ## Contato
#
# - **E-mail:** gmpaiva228@gmail.com
# - **LinkedIn:** [Link](https://www.linkedin.com/in/gabriel-marcial-6ba93a1a1/)
# ---

# %% [markdown]
# # 🔁 **Entrada e Saída de Dados em Python**

# %% [markdown]
# ### 👉 O que são entrada e saída de dados?
#
# Em um programa, **entrada de dados** é quando o usuário fornece informações ao sistema. Já a **saída de dados** é quando o sistema mostra uma informação de volta ao usuário.
#
# Em Python, usamos a função `input()` para **receber dados do usuário**, e a função `print()` para **mostrar informações na tela**.
#
# ---
#
# ### 🧱 **Funções principais:**
#
# - `input()` → Lê uma informação digitada pelo usuário (sempre retorna uma **string**).
# - `print()` → Exibe mensagens ou variáveis no console.
#
# ---

# %%
nome = input('Entre com seu nome:')
idade = int(input('Entre com a sua idade'))
# Out:
# Entre com seu nome:Gabriel
# Entre com a sua idade28

# %%
print('Seu nome é : ')
print(nome)
print('Sua Idade é ')
print(idade)
# Out:
# Seu nome é :
# Gabriel
# Sua Idade é
# 28

# %%
print('Seu nome é : ',nome,'Sua Idade é',idade)
# Out:
# Seu nome é :  Gabriel Sua Idade é 28

# %%
print(f'Seu nome é {nome}, e Sua idade é {idade}')
# Out:
# Seu nome é Gabriel, e Sua idade é 28

# %%
print(f'Seu nome é {nome}\nSua idade é {idade}')
# Out:
# Seu nome é Gabriel
# Sua idade é 28

# %%
print(f'''
-------------------
Seu nome é {nome}
-------------------
Sua idade é {idade}
-------------------
''')
# Out:
# -------------------
# Seu nome é Gabriel
# -------------------
# Sua idade é 28
# -------------------

# %% [markdown]
# ### 👉 O que são tipos de dados?
#
# Todo valor em Python pertence a um **tipo de dado**. Isso ajuda o Python a entender **como tratar e armazenar** cada informação.
#
# Você pode descobrir o tipo de uma variável ou valor usando a função `type()`.
#
# ---
#
# ### 🔍 Exemplo com `type()`:
#
# ```python
# print(type(10))         # <class 'int'>
# print(type("Python"))   # <class 'str'>
# print(type(3.14))       # <class 'float'>
# print(type(True))       # <class 'bool'>
# ```
# ---

# %%
idade = 28
type(idade)
# Out:
# int

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
nome = input('Entre com seu nome:')
type(nome)
# Out:
# Entre com seu nome:10
# str

# %% [markdown]
# ### 🔢 **Números: `int()` ou `float()`**
#
# - `int` → Números inteiros (sem casas decimais)
#   **Exemplos:** `2`, `4`, `5`, `56`
#
# - `float` → Números decimais (com ponto flutuante)
#   **Exemplos:** `2.5`, `4.5`, `5.7`
#
# ```python
# idade = 30        # int
# altura = 1.75     # float
# ```

# %%
float(30)
# Out:
# 30.0

# %%
int(1.75)
# Out:
# 1

# %%
idade = float(input('Entre com a sua idade:'))
idade
# Out:
# Entre com a sua idade:1.6
# 1.6

# %%
idade = input('Entre com a sua idade:')
print(type(idade))
idade = float(idade)
print(type(idade))
# Out:
# Entre com a sua idade:10
# <class 'str'>
# <class 'float'>

# %%
# Out:
# 10.0

# %% [markdown]
# ### 📝 **Strings: `str()`**
#
# Strings são cadeias de caracteres, sempre entre **aspas simples ou duplas**.
# **Exemplos:** `"Gabriel"`, `"Hello"`, `"Laresca"`
#
# ```python
# nome = "Gabriel"
# mensagem = "Olá, tudo bem?"
# ```

# %%
idade  = 28
print(type(idade))
idade = str(idade)
print(type(idade))
# Out:
# <class 'int'>
# <class 'str'>

# %%
idade
# Out:
# '28'

# %% [markdown]
# ### ✅ **Booleanos: `bool()`**
#
# Valores booleanos representam **lógico verdadeiro ou falso**.
# **Exemplos:** `True`, `False`
#
# ```python
# maior_de_idade = True
# tem_carteira = False
# ```

# %%
V = True

# %%
type(V)
# Out:
# bool

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool('True')
# Out:
# True

# %% [markdown]
# ### 📌 **Resumo dos principais tipos:**
#
# | Tipo      | Função     | Exemplos               |
# |-----------|------------|------------------------|
# | Inteiro   | `int()`    | `2`, `10`, `50`        |
# | Decimal   | `float()`  | `2.5`, `3.14`, `7.0`    |
# | Texto     | `str()`    | `"Python"`, `"123"`    |
# | Booleano  | `bool()`   | `True`, `False`        |
#
# ---
#
# 💬 **Dica:** Use `type()` sempre que quiser confirmar o tipo de uma variável!

# %% [markdown]
# # ➕ **Operações em Python**

# %% [markdown]
# ### 🧮 **Operadores Aritméticos**
#
# Os operadores aritméticos são usados para realizar operações matemáticas com variáveis e valores.
#
# | Operador | Descrição                                                        | Exemplo        |
# |----------|------------------------------------------------------------------|----------------|
# | `+`      | Adição - Soma dois operandos ou mais                             | `x + y`        |
# | `-`      | Subtração - Subtrai o operando direito do esquerdo               | `x - y`        |
# | `*`      | Multiplicação - Multiplica dois operandos                        | `x * y`        |
# | `/`      | Divisão - Divide o operando esquerdo pelo direito (float)        | `x / y`        |
# | `%`      | Módulo - Resto da divisão                                        | `x % y`        |
# | `//`     | Divisão inteira (piso)                                           | `x // y`       |
# | `**`     | Exponenciação - Potência                                         | `x ** y`       |
#
# ---
#
# Esses operadores são a base para a construção de expressões, condições e cálculos em Python!

# %%
10 + 10
# Out:
# 20

# %%
'10' + '10' # concatena
# Out:
# '1010'

# %%
'10' + str(10)
# Out:
# '1010'

# %%
int('10') + 10
# Out:
# 20

# %%
variavel = '--'*10
print(variavel)
# Out:
# --------------------

# %%
'--'*100
# Out:
# '--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------'

# %%
nome = 'Gabriel'
nome*10
# Out:
# 'GabrielGabrielGabrielGabrielGabrielGabrielGabrielGabrielGabrielGabriel'

# %%
entrada = input()
processamento = nome*10
print(processamento)
# Out:
# gabriel
# GabrielGabrielGabrielGabrielGabrielGabrielGabrielGabrielGabrielGabriel

# %%
num1 = int(input('entre com o primerio numero:'))
num2 = int(input('entre com o segundo numero:'))

soma = num1 + num2

print(f'A soma de {num1}+{num2} = {soma}')
# Out:
# entre com o primerio numero:10
# entre com o segundo numero:5
# A soma de 10+5 = 15

# %% [markdown]
# ### 🧾 **Operadores Comparativos (Relacionais)**
#
# Usados para comparar valores. Sempre retornam `True` ou `False`.
#
# | Operador | Descrição                                            | Exemplo        |
# |----------|------------------------------------------------------|----------------|
# | `>`      | Maior que                                            | `x > y`        |
# | `<`      | Menor que                                            | `x < y`        |
# | `==`     | Igual a                                              | `x == y`       |
# | `!=`     | Diferente de                                         | `x != y`       |
# | `>=`     | Maior ou igual a                                     | `x >= y`       |
# | `<=`     | Menor ou igual a                                     | `x <= y`       |

# %%
comparacao = 10 > 5

# %%
type(comparacao)
# Out:
# bool

# %%
10 == 5
# Out:
# False

# %%
'G' == 'g'
# Out:
# False

# %%
ord('g')
# Out:
# 103

# %%
ord('G')
# Out:
# 71

# %%
chr(71)
# Out:
# 'G'

# %% [markdown]
# ### 🔗 **Operadores Lógicos**
#
# Usados para combinar expressões booleanas.
#
# | Operador | Descrição                                     | Exemplo                    |
# |----------|-----------------------------------------------|----------------------------|
# | `and`    | Retorna `True` se **ambas** as expressões forem verdadeiras | `x > 5 and y < 10` |
# | `or`     | Retorna `True` se **uma ou ambas** forem verdadeiras        | `x > 5 or y < 10`  |
# | `not`    | Inverte o valor lógico                         | `not True` → `False`       |

# %%
10 > 5 and 3==5
# Out:
# False

# %%
10 > 5 or 3==3
# Out:
# True

# %%
not 10 > 11
# Out:
# True

# %%
11 >= 11
# Out:
# True

# %% [markdown]
# ### ***Exercicios***
#
# 1. Faça um programa que leia o nome de uma pessoa e mostre uma mensagem de boas-vindas.
# 1. Faça um Programa que peça um número e então mostre a mensagem O número informado foi [número].
# 1. Programa para somar dois números.
# 1. Programa para somar dois números com entrada do usuário.
# 1. Programa para multiplicar dois números com entrada do usuário.
# 1. Programa para calcular a potência de dois números com entrada do usuário.
# 1. Faça um programa que leia um número Inteiro e mostre na tela o seu sucessor e seu antecessor.
# 1. Crie um algoritmo que leia um número e mostre o seu dobro, triplo e raiz quadrada.
# 1. Faça um Programa que converta metros para centímetros.
# 1. Faça um código Python que leia a largura e altura de uma parede (em metros) e exiba a área da Parede.
#
# 1. Faça um programa que leia a largura e a altura de uma parede em metros, calcule a sua área e a quantidade de tinta necessária para pintá-la, sabendo que cada litro de tinta pinta uma área de 2 metros quadrados.
#
# 1. Faça um código Python que leia duas notas de um aluno, calcule e exiba a média aritmética das notas.
# 1. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.
# 1. Programa Python para verificar se um número é positivo.
# 1. Programa Python para verificar se um número é par

# %% [markdown]
# ## **Links:**
# ### **Iniciando**
#
# - [programiz](https://www.programiz.com/python-programming/statement-indentation-comments)
# - [Curso Python](https://www.youtube.com/watch?v=S9uPNppGsGo&list=PLvE-ZAFRgX8hnECDn1v9HNTI71veL3oW0&index=2)
# - [Python para Iniciantes do Zero!](https://www.youtube.com/watch?v=pGtESkyGv4U)
#
# ### **Ambiente de Desenvolvimento**
#
# - [How to Get Started With Python?](https://www.programiz.com/python-programming/first-program)
# - [Curso Python #03 - Instalando o Python3 e o IDLE](https://www.youtube.com/watch?v=VuKvR1J2LQE&list=PLvE-ZAFRgX8hnECDn1v9HNTI71veL3oW0&index=4)
# - **[Curso Python #05 - Instalando o PyCharm e o QPython3](https://www.youtube.com/watch?v=ElRd0cbXIv4&list=PLvE-ZAFRgX8hnECDn1v9HNTI71veL3oW0&index=6)**
#
# ### **Entrada e Saída de dados :**
#
# - [Tipos Primitivos e Saída de Dados](https://www.youtube.com/watch?v=hdDHg1p3YVc&list=PLvE-ZAFRgX8hnECDn1v9HNTI71veL3oW0&index=9)
#
# ### **Tipos de Dados:**
#
# - [Tipos de dados Python](https://www.programiz.com/python-programming/variables-datatypes)
# - [Variáveis em Python](https://realpython.com/python-variables/)
#
# ### ***Exercicios:***
# - [Exercicios de Python Resolvidos](https://www.youtube.com/watch?v=FNqdV5Zb_5Q&list=PLHz_AreHm4dm6wYOIW20Nyg12TAjmMGT-&index=2)
#
#  ---
# - [Ouça o podcast do Data Hackers onde e como quiser](https://datahackers.com.br/podcast/pagina-2)
# - [Eduardo Mendes](https://www.youtube.com/c/Dunossauro/videos)

# %% [markdown]
# # 🧠 **Estruturas Condicionais em Python**
