# %% [markdown]
# # _Resoluções dos Exercicios_

# %% [markdown]
# ### ***Exercicios***
#
# 1. Faça um programa que leia o nome de uma pessoa e mostre uma mensagem de boas-vindas.
# 1. Faça um Programa que peça um número e então mostre a mensagem O número informado foi [número].
# 1. Programa para somar dois números.
# 1. Programa para somar dois números com entrada do usuário.
# 1. Programa para multiplicar dois números com entrada do usuário.
# 1. Programa para calcular a potência de dois números com entrada do usuário.
# 1. Faça um programa que leia um número Inteiro e mostre na tela o seu sucessor e seu antecessor.
# 1. Crie um algoritmo que leia um número e mostre o seu dobro, triplo e raiz quadrada.
# 1. Faça um Programa que converta metros para centímetros.
# 1. Faça um código Python que leia a largura e altura de uma parede (em metros) e exiba a área da Parede.
# 1.Faça um programa que leia a largura e a altura de uma parede em metros, calcule a sua área e a quantidade de tinta necessária para pintá-la, sabendo que cada litro de tinta pinta uma área de 2 metros quadrados.
# 1. Faça um código Python que leia duas notas de um aluno, calcule e exiba a média aritmética das notas.
# 1. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.
# 1. Programa Python para verificar se um número é positivo.
# 1. Programa Python para verificar se um número é par

# %% [markdown]
# ***Questão 1***

# %%
# 1
a = 'Gabriel'

print (f'Bem vindo {a}')
# Out:
# Bem vindo Gabriel

# %%
a =  input('Entre com o nome ')
print (f'Bem vindo {a}')
# Out:
# Entre com o nome Gabriel
# Bem vindo Gabriel

# %% [markdown]
# ***Questão 2***

# %%
# 2
input("qual sua idade?")
# Out:
# qual sua idade?10
# '10'

# %%
# 2
a = int(input("qual sua idade?"))
print(f' A sua idade foi {a} anos ')
# Out:
# qual sua idade?23
#  A sua idade foi 23 anos

# %%
type(a)
# Out:
# str

# %% [markdown]
# ***Questão 3***

# %%
# 3
5 + 5
# Out:
# 10

# %%
a =  5
b =  6
soma = a + b
print(f'A soma é {soma}')
# Out:
# A soma é 56

# %% [markdown]
# ***Questão 4***

# %%
# 4
a = 20
b = 15
a + b
# Out:
# 35

# %%
a =  float(input('Entre com o primeiro numero:'))
b =  float(input('Entre com o segundo numero:'))
soma = a + b
print(f'A soma de {a} + {b}  é {soma}')
# Out:
# Entre com o primeiro numero:5
# Entre com o segundo numero:5.6
# A soma de 5.0 + 5.6  é 10.6

# %% [markdown]
# ***Questão 5***

# %%
# 5
c = 20
d = 5
c * d
# Out:
# 100

# %%
a =  float(input('Entre com o primeiro numero:'))
b =  float(input('Entre com o segundo numero:'))
produto = a * b
print(f'O prouto de {a} x {b}  é {produto}')
# Out:
# Entre com o primeiro numero:5
# Entre com o segundo numero:2
# O prouto de 5.0 x 2.0  é 10.0

# %% [markdown]
# ***Questão 6***

# %%
# 6
a = 2
b = 5
a ** b
# Out:
# 32

# %%
a =  float(input('Entre com o primeiro numero:'))
b =  float(input('Entre com o segundo numero:'))
pot = a ** b
print(f'O valor de  {a} elevado a {b}  é {pot}')
# Out:
# Entre com o primeiro numero:4
# Entre com o segundo numero:3.3
# O valor de  4.0 elevado a 3.3  é 97.00586025666546

# %% [markdown]
# ***Questão 7***

# %%
#7
n1 = int(input('digite um numero'))
a1= (n1 - 1)
a2= (n1 + 1)
print('o antescessor de {} é {} e sucessor é {}'.format(n1,a1,a2))
# Out:
# digite um numero5
# o antescessor de 5 é 4 e sucessor é 6

# %% [markdown]
# ***Questão 8***

# %%
# 8

n1 = int(input('digite um numero:'))
a1= (n1 * 2)
a2= (n1 * 3)
a3= (n1 ** (1/2))
print('o dobro de {} é {} e triplo é {} e a raiz é {}'.format(n1,a1,a2,a3))
# Out:
# digite um numero:3
# o dobro de 3 é 6 e triplo é 9 e a raiz é 1.7320508075688772

# %%
import numpy as np

np.sqrt(3)
# Out:
# 1.7320508075688772

# %% [markdown]
# ***Questão 9***

# %%
#9
d = float(input('Entre com a distancia em metros:'))

d_cm = d*100

print(f'O valor de {d} m é igual a {d_cm} cm')
# Out:
# Entre com a distancia em metros:100
# O valor de 100.0 m é igual a 10000.0 cm

# %% [markdown]
# ***Questão 10***

# %%
#10
Largura = 10
Altura = 5

print(f'minha area possui {Largura * Altura} quadrados')
# Out:
# minha area possui 50 quadrados

# %%
Largura = float(input('Entre com a Largura:'))
Altura = float(input('Entre com o comprimeto:'))

print(f'minha area possui {Largura * Altura} quadrados')
# Out:
# Entre com a Largura:2
# Entre com o comprimeto:3
# minha area possui 6.0 quadrados

# %% [markdown]
# ***Questão 11***

# %%
#11
altura = float(input('Digite a alturada parede: '))

largura = float(input('Digite a largura da parede: '))

area = altura * largura

tinta = area / 2

print('Para pintar uma area de {} é necessario {} litros de tinta'.format(area,tinta))
# Out:
# Digite a alturada parede: 5
# Digite a largura da parede: 5
# Para pintar uma area de 25.0 é necessario 12.5 litros de tinta

# %% [markdown]
# ***Questão 12***

# %%
#12
nota1 = 6.5
nota2 = 8.1

(nota1 + nota2) / 2
# Out:
# 7.3

# %%
nota1 = float(input('Entre com a primeria Nota:'))
nota2 = float(input('Entre com a segunda Nota:'))

nota_final = (nota1 + nota2) / 2
print(f'Sua nota final foi {nota_final}')
# Out:
# Entre com a primeria Nota:7
# Entre com a segunda Nota:6
# Sua nota final foi 6.5

# %% [markdown]
# ***Questão 13***

# %%
#13
hora = float(input('quanto voce ganha por hora?'))
tempo = int(input('quantas horas trabalha por dia?'))
dia = int(input('trabalha quantos dias no mês?'))
print(f'Seu sálario é {hora * tempo * dia} ')
# Out:
# quanto voce ganha por hora?5
# quantas horas trabalha por dia?20
# trabalha quantos dias no mês?20
# Seu sálario é 2000.0

# %% [markdown]
# ***Questão 14***

# %%
n = int(input('Entre com o numero:'))

resposta = n >= 0

print(f'O numero {n} é positivo ? {resposta}')
# Out:
# Entre com o numero:4
# O numero 4 é positivo ? True

# %% [markdown]
# ***Questão 15***

# %%
n = int(input('Entre com o numero:'))

resposta = n%2 == 0

print(f'O numero {n} é par ? {resposta}')
# Out:
# Entre com o numero:809494073505970345041
# O numero 809494073505970345041 é par ? False
